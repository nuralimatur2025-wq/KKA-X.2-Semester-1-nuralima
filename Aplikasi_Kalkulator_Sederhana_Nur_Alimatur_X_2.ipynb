# %% [markdown]
# <a href="https://colab.research.google.com/github/nuralimatur2025-wq/KKA-X.2-Semester-1-nuralima/blob/main/Aplikasi_Kalkulator_Sederhana_Nur_Alimatur_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Menghitung Luas Bola

# %%
panjang = int(input("masukkan panjang dari persegi panjang (cm): "))
lebar = int(input("masukkan lebar dari persegi panjang (cm): "))
luas = panjang*lebar

print(f"\nluas dari persegi panjang {luas} cm^2")
# Out:
# masukkan panjang dari persegi panjang (cm): 5
# masukkan lebar dari persegi panjang (cm): 4
#
# luas dari persegi panjang 20 cm^2

# %%
jari_jari = int(input("Masukkan jari jari dari bola (cm): "))
Luas = 4 * 22/7 * jari_jari**2

print(f"\nLuas dari bola yaitu {Luas} cm^2")
# Out:
# Masukkan jari jari dari bola (cm): 7
#
# Luas dari bola yaitu 616.0 cm^2

# %%
jari_jari = int(input("Masukkan jari jari dari bola (cm): "))
volume = 4/3 * 22/7 * jari_jari
print(f"\nVolume dari bola yaitu {volume} c^3")
# Out:
# Masukkan jari jari dari bola (cm): 7
#
# Volume dari bola yaitu 29.333333333333336 c^3
